# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os,sys,inspect, string
import re
import csv
import importlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from src.plot_utils import *
from src.dataset_getters import *

# %%
KAGGLE_DATASET_OVERVIEW = os.path.join(PROJECT_ROOT_DIR, 'data','processed','kaggle_dataset_overview.csv')

# %%
kaggle_overview = pd.read_csv(KAGGLE_DATASET_OVERVIEW)

# %%
file_path = '/home/justyna/WORKSPACE/heartbeat_classification/data/raw/kaggle/set_a/extrahls__201101091153.wav'
sampling_rate, signal = wavfile.read(file_path)

# %%
kaggle_overview.describe()
# Out:
#        recording_length  sampling_frequency  magnitude_bandwidth  \
# count        585.000000          585.000000           585.000000
# mean           6.815385        12499.829060         -2295.357265
# std            4.105222        16402.925837         16272.670377
# min            1.000000         4000.000000        -32721.000000
# 25%            3.000000         4000.000000        -14537.000000
# 50%            7.000000         4000.000000           -11.000000
# 75%            9.000000         4000.000000          3052.000000
# max           28.000000        44100.000000         32704.000000
#
#        magnitude_mean
# count      585.000000
# mean         0.702765
# std         14.075742
# min        -62.060235
# 25%         -5.519109
# 50%          0.314145
# 75%          6.407397
# max         75.758049

# %%
plot_violin_plot(figsize=10, x='set', y='magnitude_mean', hue='label',data=kaggle_overview, title='Magnitude mean of recording in each set by label')

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.barplot(y='sampling_frequency', x='set', data=kaggle_overview, hue='label')
f.suptitle('Sampling frequency in each set by label', fontsize=18, fontweight='bold')
ax.set_xlabel("Label",size = 16,alpha=0.7)
ax.set_ylabel("Sampling frequency",size = 16,alpha=0.7)
plt.legend(loc='upper left')

# %%
plot_violin_plot(title='Magnitude bandwidth by set in Kaggle', data=kaggle_overview, x='set', y='magnitude_bandwidth', hue='label', figsize=8)

# %%
plot_violin_plot(title='Recording length by set in Kaggle', data=kaggle_overview, x='set', y='recording_length', hue='label', figsize=8)

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.countplot(x='set', data=kaggle_overview, hue='label')
f.suptitle('Number of recordings in each set by label', fontsize=18, fontweight='bold')
ax.set_xlabel("Label",size = 16,alpha=0.7)
ax.set_ylabel("Number of recordings",size = 16,alpha=0.7)
plt.legend(loc='upper left')

# %%
len(kaggle_overview.loc[kaggle_overview['label'] == 'murmur']) + len(kaggle_overview.loc[kaggle_overview['label'] == 'normal']) + len(kaggle_overview.loc[kaggle_overview['label'] == 'extrahls'])
# Out:
# 480

# %%
plot_kaggle_signals_on_square_grid_by_label('a', 'murmur', 3, 20)

# %%
plot_kaggle_signals_on_square_grid_by_label('a', 'extrahls', 3, 20)

# %%
plot_kaggle_signals_on_square_grid_by_label('a', 'normal', 3, 20)

# %%
plot_kaggle_signals_on_square_grid_by_label('b', 'normal', 3, 20)

# %%
plot_kaggle_signals_on_square_grid_by_label('b', 'murmur', 3, 20)

# %%
plot_kaggle_signals_on_square_grid_by_label('b', 'extrastole', 3, 20)
