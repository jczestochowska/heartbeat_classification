# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os,sys,inspect
import re
import csv
import importlib
import matplotlib.pyplot as plt
import pandas as pd
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from src.data_utils import plot_physionet_signal, get_kaggle_label, get_random_filenames, KAGGLE_PATH, PHYSIONET_PATH,  get_physionet_labels_path, get_audio_dir_path, get_kaggle_labels_path, plot_kaggle_signal, get_random_kaggle_filenames_by_label

# %%
#PLOT RANDOM FILES FROM KAGGLE B SET
SET = 'b'
kaggle_dir_path = get_audio_dir_path(KAGGLE_PATH, SET)
filenames = get_random_filenames(how_many=10, directory=kaggle_dir_path)
for filename in filenames:
    plot_kaggle_signal(filename, SET)

# %%
#PLOT RANDOM FILES WITH 'NORMAL' LABEL
SET = 'b'
kaggle_dir_path = get_audio_dir_path(KAGGLE_PATH, SET)
label_filenames = get_random_kaggle_filenames_by_label(how_many=10, directory=kaggle_dir_path, label='normal')
for filename in label_filenames:
    plot_kaggle_signal(filename, SET)

# %%
#PLOT RANDOM FILES WITH 'EXTRASYSTOLE' LABEL
SET='b'
kaggle_dir_path = get_audio_dir_path(KAGGLE_PATH, SET)
label_filenames = get_random_kaggle_filenames_by_label(how_many=10, directory=kaggle_dir_path, label='extrastole')
for filename in label_filenames:
    plot_kaggle_signal(filename, SET)

# %%
#PLOT RANDOM FILES WITH 'MURMUR' LABEL
label_filenames = get_random_kaggle_filenames_by_label(how_many=10, directory=kaggle_dir_path, label='murmur')
for filename in label_filenames:
    plot_kaggle_signal(filename, SET)

# %%
#PLOT RANDOM FILES WITH 'EXTRASYSTOLE' LABEL
SET = 'a'
kaggle_dir_path = get_audio_dir_path(KAGGLE_PATH, SET)
label_filenames = get_random_kaggle_filenames_by_label(how_many=10, directory=kaggle_dir_path, label='extrahls')
for filename in label_filenames:
    plot_kaggle_signal(filename, SET)

# %%
SET = 'a'
physionet_dir_path = get_audio_dir_path(PHYSIONET_PATH, SET)
physio_random_filenames = get_random_filenames(how_many=20, directory=physionet_dir_path)
for filename in physio_random_filenames:
    plot_physionet_signal(filename, SET)
