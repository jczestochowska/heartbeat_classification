# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os,sys,inspect
import re
import csv
import importlib
import matplotlib.pyplot as plt
import pandas as pd
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from src.plot_utils import *
from src.dataset_getters import *

# %%
SET = 'b'

# %%
plot_kaggle_signals(5, SET)

# %%
#PLOT RANDOM FILES WITH 'NORMAL' LABEL
SET = 'b'
kaggle_dir_path = get_audio_dir_path(KAGGLE_PATH, SET)
label_filenames = get_random_kaggle_filenames_by_label(how_many=10, directory=kaggle_dir_path, label='normal')
for filename in label_filenames:
    plot_kaggle_signal(filename, SET)

# %%
plot_kaggle_signals_by_label(5, SET, 'normal')

# %%
#PLOT RANDOM FILES WITH 'EXTRASYSTOLE' LABEL
plot_kaggle_signals_by_label(5, SET, 'extrastole')

# %%
#PLOT RANDOM FILES WITH 'MURMUR' LABEL
plot_kaggle_signals_by_label(5, SET, 'murmur')

# %%
#PLOT RANDOM FILES WITH 'EXTRASYSTOLE' LABEL
plot_kaggle_signals_by_label(5, 'a', 'extrahls')

# %%
plot_physionet_signals(10, SET)

# %%
plot_physionet_signals_by_label(10, SET, 'abnormal')
# Out:
# /home/justyna/WORKSPACE/heartbeat_classification/src/dataset_getters.py:40: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filenames = labels.loc[labels['label'] == label][labels['filename'].str.match(set_letter)].sample(how_many)[
