# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

from src.data_analysis import get_kaggle_label, get_random_filenames, KAGGLE_PATH,\
    get_audio_dir_path, get_kaggle_labels_path, plot_kaggle_signal

# %%
SET = 'a'
dir_path = get_audio_dir_path(KAGGLE_PATH, SET)
filenames = get_random_filenames(how_many=30, directory=dir_path)

# %%
for filename in filenames:
    plot_kaggle_signal(filename, SET)
# Out:
# Number of samples 396900
# Sampling frequency 44100
# Number of samples 391787
# Sampling frequency 44100
# Number of samples 391787
# Sampling frequency 44100
# Number of samples 353414
# Sampling frequency 44100
# Number of samples 309467
# Sampling frequency 44100
# Number of samples 396900
# Sampling frequency 44100
# Number of samples 396900
# Sampling frequency 44100
# Number of samples 349958
# Sampling frequency 44100
# Number of samples 349958
# Sampling frequency 44100
# Number of samples 354151
# Sampling frequency 44100
# Number of samples 342727
# Sampling frequency 44100
# Number of samples 396900
# Sampling frequency 44100
# Number of samples 396900
# Sampling frequency 44100
# Number of samples 396900
# Sampling frequency 44100
# Number of samples 396900
# Sampling frequency 44100
# Number of samples 396900
# Sampling frequency 44100
# Number of samples 396900
# Sampling frequency 44100
# Number of samples 262646
# Sampling frequency 44100
# Number of samples 218903
# ...
