# %%
import os,sys,inspect
import re
import csv
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

from src.data_utils import get_kaggle_label, get_random_filenames, KAGGLE_PATH,\
    get_audio_dir_path, get_kaggle_labels_path, plot_kaggle_signal

# %%
SET = 'a'
dir_path = get_audio_dir_path(KAGGLE_PATH, SET)
filenames = get_random_filenames(how_many=20, directory=dir_path)

# %%
for filename in filenames:
    plot_kaggle_signal(filename, SET)
