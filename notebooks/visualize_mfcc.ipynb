# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
import matplotlib.pyplot as plt
from librosa import display

# %%
from config import PROJECT_ROOT_DIR
from src.feature_extraction import *
from src.dataset_getters import get_random_filenames

# %%
PHYSIONET_DIR = os.path.join(PROJECT_ROOT_DIR, 'data', 'processed', 'preprocessed', 'physionet')
TRAINING_DIR = os.path.join(PHYSIONET_DIR, 'training')
TEST_DIR = os.path.join(PHYSIONET_DIR, 'test')

# %%
random_train_files = get_random_filenames(directory=TRAINING_DIR, how_many=5)
random_train_files
# Out:
# ['abnormal_physionet_919d17423dc54f52aefe0c5ea9d87dd0.wav',
#  'abnormal_physionet_968b8b19a97045da85addd123e7d5806.wav',
#  'normal_physionet_1af5592a3c894c9fb686e747fc47b97e.wav',
#  'abnormal_physionet_58328e0667dc49b9b1d0e28ae24785d0.wav',
#  'normal_physionet_b2faa20faca9404b99c4216d35d7d318.wav']

# %%
normal_random_file_path = os.path.join(TRAINING_DIR, random_train_files[2])
normal_random_file1_path = os.path.join(TRAINING_DIR, random_train_files[4])

abnormal_random_file_path = os.path.join(TRAINING_DIR, random_train_files[0])
abnormal_random_file1_path = os.path.join(TRAINING_DIR, random_train_files[1])
abnormal_random_file2_path = os.path.join(TRAINING_DIR, random_train_files[3])

# %%
plt.figure(figsize=(10, 4))
display.specshow(get_mfcc(normal_random_file_path), x_axis='time',cmap='magma')
plt.colorbar()
plt.title('normal MFCC')
plt.tight_layout()

# %%
plt.figure(figsize=(10, 4))
display.specshow(get_mfcc(normal_random_file1_path), x_axis='time',cmap='magma')
plt.colorbar()
plt.title('normal MFCC')
plt.tight_layout()

# %%
plt.figure(figsize=(10, 4))
display.specshow(get_mfcc(abnormal_random_file_path), x_axis='time',cmap='magma')
plt.colorbar()
plt.title('abnormal MFCC')
plt.tight_layout()

# %%
plt.figure(figsize=(10, 4))
display.specshow(get_mfcc(abnormal_random_file1_path), x_axis='time',cmap='magma')
plt.colorbar()
plt.title('abnormal MFCC')
plt.tight_layout()

# %%
plt.figure(figsize=(10, 4))
display.specshow(get_mfcc(abnormal_random_file2_path), x_axis='time', cmap='magma')
plt.colorbar()
plt.title('abnormal MFCC')
plt.tight_layout()
