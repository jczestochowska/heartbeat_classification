# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os,sys,inspect, string
import re
import csv
import importlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy.io import wavfile
from itertools import combinations, product
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from src.plot_utils import *
from src.dataset_getters import *

# %%
PHYSIONET_DATASET_OVERVIEW = os.path.join(PROJECT_ROOT_DIR, 'data','processed','physionet_dataset_overview.csv')

# %%
physionet_overview = pd.read_csv(PHYSIONET_DATASET_OVERVIEW)

# %%
physionet_overview.describe()
# Out:
#         Unnamed: 0  recording_length  sampling_frequency  magnitude_bandwidth  \
# count  3240.000000       3240.000000              3240.0          3240.000000
# mean   1619.500000         22.482099              2000.0         -2939.239815
# std     935.451763         12.411601                 0.0         16508.779575
# min       0.000000          5.000000              2000.0        -32768.000000
# 25%     809.750000         13.000000              2000.0        -14577.250000
# 50%    1619.500000         21.000000              2000.0         -6784.500000
# 75%    2429.250000         31.000000              2000.0         10786.000000
# max    3239.000000        122.000000              2000.0         32604.000000
#
#        magnitude_mean
# count     3240.000000
# mean      -848.891227
# std       1914.534215
# min     -14404.927375
# 25%       -832.071149
# 50%        -34.680178
# 75%         13.265484
# max       2341.119402

# %%
plot_violin_plot(figsize=10, x='set', y='magnitude_mean', hue='label',data=physionet_overview, title='Magnitude mean of recording in each set by label')

# %%
plot_physionet_signals_on_square_grid_by_label(set_letter='a', label=1, grid_size=3, figsize=20)
# Out:
# /home/justyna/WORKSPACE/heartbeat_classification/src/dataset_getters.py:44: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filenames = labels.loc[labels['label'] == label][labels['filename'].str.match(set_letter)].sample(how_many)[

# %%
plot_physionet_signals_on_square_grid_by_label(set_letter='a', label=-1, grid_size=3, figsize=20)
# Out:
# /home/justyna/WORKSPACE/heartbeat_classification/src/dataset_getters.py:44: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filenames = labels.loc[labels['label'] == label][labels['filename'].str.match(set_letter)].sample(how_many)[

# %%
plot_physionet_signals_on_square_grid_by_label(set_letter='b', label=1, grid_size=3, figsize=20)
# Out:
# /home/justyna/WORKSPACE/heartbeat_classification/src/dataset_getters.py:44: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filenames = labels.loc[labels['label'] == label][labels['filename'].str.match(set_letter)].sample(how_many)[

# %%
plot_physionet_signals_on_square_grid_by_label(set_letter='b', label=-1, grid_size=3, figsize=20)
# Out:
# /home/justyna/WORKSPACE/heartbeat_classification/src/dataset_getters.py:44: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filenames = labels.loc[labels['label'] == label][labels['filename'].str.match(set_letter)].sample(how_many)[

# %%
plot_physionet_signals_on_square_grid_by_label(set_letter='c', label=1, grid_size=3, figsize=20)
# Out:
# /home/justyna/WORKSPACE/heartbeat_classification/src/dataset_getters.py:44: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filenames = labels.loc[labels['label'] == label][labels['filename'].str.match(set_letter)].sample(how_many)[

# %%
plot_physionet_signals_on_square_grid_by_label(set_letter='c', label=-1, grid_size=2, figsize=20)
# Out:
# /home/justyna/WORKSPACE/heartbeat_classification/src/dataset_getters.py:44: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filenames = labels.loc[labels['label'] == label][labels['filename'].str.match(set_letter)].sample(how_many)[

# %%
plot_physionet_signals_on_square_grid_by_label('d', 1, 3, 20)
# Out:
# /home/justyna/WORKSPACE/heartbeat_classification/src/dataset_getters.py:44: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filenames = labels.loc[labels['label'] == label][labels['filename'].str.match(set_letter)].sample(how_many)[

# %%
plot_physionet_signals_on_square_grid_by_label(set_letter='d', label=-1, grid_size=3, figsize=20)
# Out:
# /home/justyna/WORKSPACE/heartbeat_classification/src/dataset_getters.py:44: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filenames = labels.loc[labels['label'] == label][labels['filename'].str.match(set_letter)].sample(how_many)[

# %%
plot_physionet_signals_on_square_grid_by_label(set_letter='e', label=1, grid_size=3, figsize=20)
# Out:
# /home/justyna/WORKSPACE/heartbeat_classification/src/dataset_getters.py:44: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filenames = labels.loc[labels['label'] == label][labels['filename'].str.match(set_letter)].sample(how_many)[

# %%
plot_physionet_signals_on_square_grid_by_label(set_letter='e', label=-1, grid_size=3, figsize=20)
# Out:
# /home/justyna/WORKSPACE/heartbeat_classification/src/dataset_getters.py:44: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filenames = labels.loc[labels['label'] == label][labels['filename'].str.match(set_letter)].sample(how_many)[

# %%
plot_physionet_signals_on_square_grid_by_label(set_letter='f', label=1, grid_size=3, figsize=20)
# Out:
# /home/justyna/WORKSPACE/heartbeat_classification/src/dataset_getters.py:44: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filenames = labels.loc[labels['label'] == label][labels['filename'].str.match(set_letter)].sample(how_many)[

# %%
plot_physionet_signals_on_square_grid_by_label(set_letter='f', label=-1, grid_size=3, figsize=20)
# Out:
# /home/justyna/WORKSPACE/heartbeat_classification/src/dataset_getters.py:44: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filenames = labels.loc[labels['label'] == label][labels['filename'].str.match(set_letter)].sample(how_many)[

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.barplot(y='sampling_frequency', x='set', data=physionet_overview, hue='label')
f.suptitle('Sampling frequency in each set by label', fontsize=18, fontweight='bold')
ax.set_xlabel("Label",size = 16,alpha=0.7)
ax.set_ylabel("Sampling frequency",size = 16,alpha=0.7)
plt.legend(loc='upper left')

# %%
physionet_overview.describe()
# Out:
#         Unnamed: 0  recording_length  sampling_frequency  magnitude_bandwidth  \
# count  3240.000000       3240.000000              3240.0          3240.000000
# mean   1619.500000         22.482099              2000.0         -2939.239815
# std     935.451763         12.411601                 0.0         16508.779575
# min       0.000000          5.000000              2000.0        -32768.000000
# 25%     809.750000         13.000000              2000.0        -14577.250000
# 50%    1619.500000         21.000000              2000.0         -6784.500000
# 75%    2429.250000         31.000000              2000.0         10786.000000
# max    3239.000000        122.000000              2000.0         32604.000000
#
#        magnitude_mean
# count     3240.000000
# mean      -848.891227
# std       1914.534215
# min     -14404.927375
# 25%       -832.071149
# 50%        -34.680178
# 75%         13.265484
# max       2341.119402

# %%
sns.set(style="whitegrid", palette="pastel", color_codes=True)

f, ax = plt.subplots(figsize=(8, 8))

sns.violinplot(x="set",y="magnitude_bandwidth",hue="label", data=physionet_overview)
sns.despine(left=True)

f.suptitle('Magnitude bandwidth by set in PhysioNet', fontsize=18, fontweight='bold')
ax.set_xlabel("Set",size = 16,alpha=0.7)
ax.set_ylabel("Bandwidth",size = 16,alpha=0.7)
plt.legend(loc='upper left')

# %%
sns.set(style="whitegrid", palette="pastel", color_codes=True)

f, ax = plt.subplots(figsize=(8, 8))

sns.violinplot(x="set",y="recording_length",hue="label", data=physionet_overview)
sns.despine(left=True)

f.suptitle('Recording length by set in PhysioNet', fontsize=18, fontweight='bold')
ax.set_xlabel("Set",size = 16,alpha=0.7)
ax.set_ylabel("Recording length",size = 16,alpha=0.7)
plt.legend(loc='upper left')

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.countplot(x='set', data=physionet_overview, hue='label')
f.suptitle('Number of recordings in each set by label', fontsize=18, fontweight='bold')
ax.set_xlabel("Label",size = 16,alpha=0.7)
ax.set_ylabel("Number of recordings",size = 16,alpha=0.7)
plt.legend(loc='upper left')

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.countplot(x='label', data=physionet_overview)
f.suptitle('Number of recordings by label in PhysioNet', fontsize=18, fontweight='bold')
ax.set_xlabel("Label",size = 16,alpha=0.7)
ax.set_ylabel("Number of recordings",size = 16,alpha=0.7)
plt.legend(loc='upper left')
# Out:
# No handles with labels found to put in legend.
